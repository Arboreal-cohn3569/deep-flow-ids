# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 01. Exploratory Data Analysis (CIC-IDS2017)\n",
    "Inspect class distribution, missing values, and data shapes."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import glob\n",
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "\n",
    "files = glob.glob('../data/raw/*.csv')\n",
    "if files:\n",
    "    df = pd.read_csv(files[0], skipinitialspace=True, nrows=100000)\n",
    "    df.columns = df.columns.str.strip()\n",
    "    print(f\"Loaded {files[0]} | Shape: {df.shape}\")\n",
    "    \n",
    "    plt.figure(figsize=(10, 5))\n",
    "    df['Label'].value_counts().plot(kind='bar', color='royalblue')\n",
    "    plt.title('Sample Class Distribution')\n",
    "    plt.xlabel('Traffic Class')\n",
    "    plt.ylabel('Count')\n",
    "    plt.xticks(rotation=45)\n",
    "    plt.show()\n",
    "else:\n",
    "    print('No CSV files found in ../data/raw/')"
   ]
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
